# %%
# import all necessary modules
import os
import sys
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# /Users/saroshfarhan/Documents/DataScience/AI_Agent-1/venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.18) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ✅ ADK components imported successfully.

# %%
# read api key from .env file
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
     print("🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details")
else:
    print("🔑 API Key loaded successfully ✅ .")
# Out:
# 🔑 API Key loaded successfully ✅ .

# %% [markdown]
# ### Defing root agent

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %% [markdown]
# ### Creating runner for agent

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %% [markdown]
# ### Runnnig the agent

# %%
# not running here in notebbok but runs in web interface
# response = await runner.run_debug("What is Agent Development Kit from Google? What languages is the SDK available in?")

# %% [markdown]
# The below command creates an agent called sample-agent and we can run it in command line by
#
# CLI
# ```
# adk run sample-agent
# ```
#
# or
#
# Web browser
# ```
# adk web --port 8080
# ```

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# /Users/saroshfarhan/Documents/DataScience/AI_Agent-1/venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.18) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
#
# Agent created in /Users/saroshfarhan/Documents/DataScience/AI_Agent-1/day1_self_study/sample-agent:
# - .env
# - __init__.py
# - agent.py
